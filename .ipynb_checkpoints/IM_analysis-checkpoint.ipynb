# %%
import pandas as pd
import ast
import numpy as np
from datetime import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
pd.set_option('mode.chained_assignment', None)

# %%
# Reading data from csv file
df = pd.read_csv("200_IM_results.csv")

# %%
df.head(10)
# Out:
#            Swimmer name Year of birth        Country     Time  \
# 0          CSEH, Laszlo          1985        Hungary  1:57.61
# 1  JANUSAITIS, Vytautas          1981      Lithuania  1:59.72
# 2    BOGGIATTO, Alessio          1981          Italy  2:00.24
# 3     BEREZUTSKIY, Igor          1984         Russia  2:01.11
# 4    TUMIOTTO, Leonardo          1983          Italy  2:01.52
# 5     KEREKJARTO, Tamas          1979        Hungary  2:01.61
# 6      FEBBRARO, Nicola          1981          Italy  2:01.70
# 7        FRANCIS, Robin          1982  Great Britain  2:01.90
# 8          CARRY, David          1981  Great Britain  2:02.16
# 9          TAIT, Gregor          1979  Great Britain  2:02.20
#
#                                  Splits         Date
# 0  ['24.82', '29.04', '35.18', '28.57']  28 Jul 2005
# 1  ['25.83', '30.41', '34.74', '28.74']  27 Jul 2005
# 2  ['26.42', '31.24', '34.32', '28.26']  27 Jul 2005
# 3  ['26.11', '30.78', '35.79', '28.43']  27 Jul 2005
# 4  ['26.72', '31.04', '34.31', '29.45']   6 Apr 2005
# 5           ['26.29', '31.05', '1:04.']  25 Jun 2005
# 6  ['26.84', '31.25', '34.87', '28.74']  10 Jun 2005
# 7                                    []   7 Aug 2005
# 8  ['27.29', '31.72', '35.17', '27.98']  27 May 2005
# 9                                    []   8 Aug 2005

# %%
# Inserting "0" value before time to get a format able to convert 
# Deleting strange "M" letter in time value
# Converting Time column to datetime format (only time)
df["Time"] = df.apply(lambda row: ("{}"+row["Time"]).format("0"), axis = 1)
df["Time"] = df.apply(lambda row: row["Time"].rstrip("M"), axis=1)
df["Time"] = pd.to_datetime(df["Time"], format="%M:%S.%f").dt.time

# %%
# Sorting rows by Time column
df = df.sort_values(by="Time", ignore_index=True)

# %%
df
# Out:
#               Swimmer name Year of birth  Country             Time  \
# 0             CSEH, Laszlo          1985  Hungary  00:01:53.480000
# 1          SWITKOWSKI, Jan          1994   Poland  00:01:54.100000
# 2        BROMER, Viktor B.          1993  Denmark  00:01:54.470000
# 3         KENDERESI, Tamas          1996  Hungary  00:01:54.790000
# 4         KOPTELOV, Evgeny          1993   Russia  00:01:54.790000
# ...                    ...           ...      ...              ...
# 4920  IPSEN, Anton Oerskov          1994  Denmark  00:02:08.390000
# 4921           MAURI, Luca          1995    Italy  00:02:08.390000
# 4922        ZELLMANN, Poul          1995  Germany  00:02:08.390000
# 4923          LEANDER, Tor          1999   Sweden  00:02:08.390000
# 4924       CASTERA, Mathis          1996   France  00:02:08.390000
#
#                                     Splits         Date
# 0     ['25.18', '29.03', '29.33', '29.94']   5 Aug 2015
# 1     ['25.96', '29.22', '29.68', '29.24']   5 Aug 2015
# 2     ['25.96', '28.79', '29.42', '30.30']   4 Aug 2015
# 3     ['26.55', '29.89', '29.74', '28.61']  30 Jun 2015
# 4     ['26.04', '29.15', '30.17', '29.43']   7 Jul 2015
# ...                                    ...          ...
# 4920  ['27.78', '33.98', '36.94', '29.69']  13 Jul 2012
# 4921  ['27.88', '34.64', '36.33', '29.54']   8 Aug 2012
# 4922                                    []  16 Dec 2012
# 4923  ['27.53', '33.61', '36.20', '31.05']   8 Jul 2018
# 4924  ['29.35', '32.20', '38.37', '28.47']  30 Jul 2016
#
# [4925 rows x 6 columns]

# %%
# Inserting Ranking column
df.insert(loc=0, column='Ranking', value=np.arange(len(df))+1)

# %%
# Convert Splits column from string that looks like a list to list
df["Splits"] = df.apply(lambda row: ast.literal_eval(row['Splits']), axis=1)

# %%
df["Year of birth"].unique()
# Out:
# array(['1985', '1994', '1993', '1996', '1984', '1976', '1991', '1989',
#        '1995', '1992', '1997', '1978', '1998', '1988', '1983', '1986',
#        '1980', '1987', '1982', '1979', '1990', '1999', '1981', '2000',
#        '2001', '1977', '2002', '2003', '1975', '1970', '1974', '2004',
#        '??', '1966', '2005'], dtype=object)

# %%
df.groupby("Year of birth").size()
# Out:
# Year of birth
# 1966      2
# 1970      5
# 1974      1
# 1975      4
# 1976      6
# 1977      5
# 1978     20
# 1979     14
# 1980     23
# 1981     47
# 1982     28
# 1983     53
# 1984    109
# 1985    157
# 1986    156
# 1987    147
# 1988    297
# 1989    254
# 1990    233
# 1991    274
# 1992    367
# 1993    305
# 1994    388
# 1995    339
# 1996    298
# 1997    327
# 1998    267
# 1999    251
# 2000    241
# 2001    157
# 2002    105
# 2003     34
# 2004      9
# 2005      1
# ??        1
# dtype: int64

# %%
# Remove 1 row with Year of birth value == "??"
df = df[df["Year of birth"] != "??"]

# %%
# Convert Year of birth column from string to int
df["Year of birth"] = pd.to_numeric(df["Year of birth"])

# %%
# Creating function that replace months name with their number equivalent
def date_converter(date):
    months = {"Jan": "01", "Feb": "02", "Mar": "03", "Apr": "04", "May": "05", "Jun": "06", 
              "Jul": "07", "Aug": "08", "Sep": "09", "Oct": "10", "Nov": "11", "Dec": "12"}
    for month in months.keys():
        if month in date.split():
            date = date.replace(month, months[month])
            break
    return date

# %%
# Replace months name with their number equivalent
df["Date"] = df.apply(lambda row: date_converter(row["Date"]), axis = 1)

# %%
# Converting Date column from string to date format
df["Date"] = pd.to_datetime(df["Date"])

# %% [markdown]
# # SPLITS ANALYSIS

# %%
# Getting only these rows that have all split times
splits_df = df[df["Splits"].map(len) == 4]

# %%
splits_df
# Out:
#       Ranking          Swimmer name  Year of birth  Country             Time  \
# 0           1          CSEH, Laszlo           1985  Hungary  00:01:53.480000
# 1           2       SWITKOWSKI, Jan           1994   Poland  00:01:54.100000
# 2           3     BROMER, Viktor B.           1993  Denmark  00:01:54.470000
# 3           4      KENDERESI, Tamas           1996  Hungary  00:01:54.790000
# 4           5      KOPTELOV, Evgeny           1993   Russia  00:01:54.790000
# ...       ...                   ...            ...      ...              ...
# 4918     4919          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4920     4921  IPSEN, Anton Oerskov           1994  Denmark  00:02:08.390000
# 4921     4922           MAURI, Luca           1995    Italy  00:02:08.390000
# 4923     4924          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4924     4925       CASTERA, Mathis           1996   France  00:02:08.390000
#
#                             Splits       Date
# 0     [25.18, 29.03, 29.33, 29.94] 2015-05-08
# 1     [25.96, 29.22, 29.68, 29.24] 2015-05-08
# 2     [25.96, 28.79, 29.42, 30.30] 2015-04-08
# 3     [26.55, 29.89, 29.74, 28.61] 2015-06-30
# 4     [26.04, 29.15, 30.17, 29.43] 2015-07-07
# ...                            ...        ...
# 4918  [27.53, 33.61, 36.20, 31.05] 2018-08-07
# 4920  [27.78, 33.98, 36.94, 29.69] 2012-07-13
# 4921  [27.88, 34.64, 36.33, 29.54] 2012-08-08
# 4923  [27.53, 33.61, 36.20, 31.05] 2018-08-07
# 4924  [29.35, 32.20, 38.37, 28.47] 2016-07-30
#
# [3429 rows x 7 columns]

# %%
# Converting split values from string to float
splits_df["Splits"] = splits_df.apply(lambda row: [float(split) for split in row["Splits"]], axis=1)

# %%
# Creating columns with split time for each style of individual medley
splits_df[["Butterfly", "Backstroke", "Breastroke", "Freestyle"]] = pd.DataFrame(splits_df["Splits"].values.tolist(), 
                                                                                 index=splits_df.index)

# %%
# Dropping Splits column
splits_df = splits_df.drop("Splits", axis = 1 )

# %%
# Creating function to convert Time from datetime format to float in seconds
def to_seconds(time):
    return time.minute*60 + time.second + time.microsecond/1000000

# %%
# Creating column with Time in seconds
splits_df["Time in secs"] = splits_df.apply(lambda row: to_seconds(row["Time"]), axis = 1)

# %%
splits_df = splits_df[splits_df.columns[[0,1,2,3,4,10,6,7,8,9,5]]]

# %%
splits_df
# Out:
#       Ranking          Swimmer name  Year of birth  Country             Time  \
# 0           1          CSEH, Laszlo           1985  Hungary  00:01:53.480000
# 1           2       SWITKOWSKI, Jan           1994   Poland  00:01:54.100000
# 2           3     BROMER, Viktor B.           1993  Denmark  00:01:54.470000
# 3           4      KENDERESI, Tamas           1996  Hungary  00:01:54.790000
# 4           5      KOPTELOV, Evgeny           1993   Russia  00:01:54.790000
# ...       ...                   ...            ...      ...              ...
# 4918     4919          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4920     4921  IPSEN, Anton Oerskov           1994  Denmark  00:02:08.390000
# 4921     4922           MAURI, Luca           1995    Italy  00:02:08.390000
# 4923     4924          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4924     4925       CASTERA, Mathis           1996   France  00:02:08.390000
#
#       Time in secs  Butterfly  Backstroke  Breastroke  Freestyle       Date
# 0           113.48      25.18       29.03       29.33      29.94 2015-05-08
# 1           114.10      25.96       29.22       29.68      29.24 2015-05-08
# 2           114.47      25.96       28.79       29.42      30.30 2015-04-08
# 3           114.79      26.55       29.89       29.74      28.61 2015-06-30
# 4           114.79      26.04       29.15       30.17      29.43 2015-07-07
# ...            ...        ...         ...         ...        ...        ...
# 4918        128.39      27.53       33.61       36.20      31.05 2018-08-07
# 4920        128.39      27.78       33.98       36.94      29.69 2012-07-13
# 4921        128.39      27.88       34.64       36.33      29.54 2012-08-08
# 4923        128.39      27.53       33.61       36.20      31.05 2018-08-07
# 4924        128.39      29.35       32.20       38.37      28.47 2016-07-30
#
# [3429 rows x 11 columns]

# %% [markdown]
# ## Butterfly

# %%
"""
Calculating which style is the worst for each swimmer. This measure is calculated based on mean result for each style.
Measure is not based on comparing with the best result to avoid outliers. Sometimes swimmer is trying to beat his own record
only for one style, not whole distance. Then this split time is not typical for the IM distance.
Ratio = split_time / mean_time
"""
# Out:
# '\nCalculating which style is the worst for each swimmer. This measure is calculated based on mean result for each style.\nMeasure is not based on comparing with the best result to avoid outliers. Sometimes swimmer is trying to beat his own record\nonly for one style, not whole distance. Then this split time is not typical for the IM distance.\nRatio = split_time / mean_time\n'

# %%
# Displaying 5 the best results in Butterfly split
splits_df.nsmallest(5, "Butterfly")
# Out:
#       Ranking      Swimmer name  Year of birth   Country             Time  \
# 441       442    POPOV, Dmitriy           2000    Russia  00:02:00.860000
# 2741     2742  STRAVIUS, Jeremy           1988    France         00:02:06
# 3763     3764  MILADINOV, Josif           2003  Bulgaria  00:02:07.360000
# 96         97      CSEH, Laszlo           1985   Hungary  00:01:58.170000
# 72         73  STRAVIUS, Jeremy           1988    France  00:01:57.890000
#
#       Time in secs  Butterfly  Backstroke  Breastroke  Freestyle       Date
# 441         120.86      17.47       40.63       25.33      37.43 2015-07-31
# 2741        126.00      24.36       34.46       40.22      26.96 2016-03-29
# 3763        127.36      24.41       33.37       37.78      31.80 2019-04-14
# 96          118.17      24.46       29.54       35.17      29.00 2016-05-17
# 72          117.89      24.61       29.69       35.67      27.92 2013-11-04

# %%
# 17.47 in 50m butterfly is impossible, because World Record equals to 22,27 (01.07.2018). Probably measuring system problem.
# So we have to drop this row in our analysis
splits_df = splits_df[splits_df["Butterfly"] != 17.47]

# %%
splits_df.nsmallest(5, "Butterfly")
# Out:
#       Ranking      Swimmer name  Year of birth   Country             Time  \
# 2741     2742  STRAVIUS, Jeremy           1988    France         00:02:06
# 3763     3764  MILADINOV, Josif           2003  Bulgaria  00:02:07.360000
# 96         97      CSEH, Laszlo           1985   Hungary  00:01:58.170000
# 72         73  STRAVIUS, Jeremy           1988    France  00:01:57.890000
# 7           8      CSEH, Laszlo           1985   Hungary  00:01:55.180000
#
#       Time in secs  Butterfly  Backstroke  Breastroke  Freestyle       Date
# 2741        126.00      24.36       34.46       40.22      26.96 2016-03-29
# 3763        127.36      24.41       33.37       37.78      31.80 2019-04-14
# 96          118.17      24.46       29.54       35.17      29.00 2016-05-17
# 72          117.89      24.61       29.69       35.67      27.92 2013-11-04
# 7           115.18      24.72       29.06       33.62      27.78 2009-07-29

# %%
splits_df.nlargest(5, "Butterfly")
# Out:
#       Ranking        Swimmer name  Year of birth  Country             Time  \
# 4924     4925     CASTERA, Mathis           1996   France  00:02:08.390000
# 4233     4234  CHRISTENSEN, Chris           1988  Denmark  00:02:07.860000
# 4378     4379    ROSSO, Christian           1995    Italy  00:02:07.980000
# 4381     4382    ROSSO, Christian           1995    Italy  00:02:07.980000
# 3703     3704     GEZMIS, Ergecan           1998   Turkey  00:02:07.290000
#
#       Time in secs  Butterfly  Backstroke  Breastroke  Freestyle  ...  \
# 4924        128.39      29.35       32.20       38.37      28.47  ...
# 4233        127.86      28.87       32.07       35.98      30.94  ...
# 4378        127.98      28.79       33.51       36.63      29.05  ...
# 4381        127.98      28.79       33.51       36.63      29.05  ...
# 3703        127.29      28.77       32.42       37.35      28.75  ...
#
#      Backstroke ratio mean  Breastroke ratio mean  Freestyle ratio mean  \
# 4924              1.002457               1.070528              0.950215
# 4233              0.998410               1.003847              1.032653
# 4378              1.043240               1.021982              0.969573
# 4381              1.043240               1.021982              0.969573
# 3703              1.009306               1.042070              0.959560
#
#       Butterfly ratio best  Backstroke ratio best  Breastroke ratio best  \
# 4924              1.204844               1.129825               1.308217
# 4233              1.185140               1.125263               1.226730
# 4378              1.181856               1.175789               1.248892
# 4381              1.181856               1.175789               1.248892
# 3703              1.181034               1.137544               1.273440
#
#       Freestyle ratio best  Worst style mean  Worst style best  \
# 4924              1.089969         Butterfly        Breastroke
# 4233              1.184533         Butterfly        Breastroke
# 4378              1.112175         Butterfly        Breastroke
# 4381              1.112175         Butterfly        Breastroke
# 3703              1.100689         Butterfly        Breastroke
#
#      Ranking interval
# 4924     (4800, 4925]
# 4233     (4200, 4300]
# 4378     (4300, 4400]
# 4381     (4300, 4400]
# 3703     (3700, 3800]
#
# [5 rows x 22 columns]

# %%
# There aren't impossible results for butterfly split, so computing mean reasult
butterfly_mean = float(splits_df[["Butterfly"]].mean())
print(butterfly_mean)
# Out:
# 24.36
# 26.911820303383898

# %% [markdown]
# ## Backstroke

# %%
splits_df.nsmallest(5, "Backstroke")
# Out:
#     Ranking        Swimmer name  Year of birth  Country             Time  \
# 19       20        CSEH, Laszlo           1985  Hungary  00:01:56.520000
# 2         3   BROMER, Viktor B.           1993  Denmark  00:01:54.470000
# 8         9  SKVORTSOV, Nikolay           1984   Russia  00:01:55.220000
# 78       79    VAZAIOS, Andreas           1994   Greece  00:01:57.980000
# 61       62        CSEH, Laszlo           1985  Hungary  00:01:57.730000
#
#     Time in secs  Butterfly  Backstroke  Breastroke  Freestyle       Date
# 19        116.52      24.95       28.50       34.56      28.51 2008-08-15
# 2         114.47      25.96       28.79       29.42      30.30 2015-04-08
# 8         115.22      25.57       28.80       29.96      30.89 2007-03-28
# 78        117.98      25.83       28.84       34.41      28.90 2017-07-26
# 61        117.73      24.94       28.88       34.73      29.18 2010-11-08

# %%
splits_df.nlargest(5, "Backstroke")
# Out:
#       Ranking         Swimmer name  Year of birth  Country             Time  \
# 3489     3490  KARPENKO, Oleksandr           1995  Ukraine  00:02:07.040000
# 4437     4438   RAEISAENEN, Daniel           1999   Sweden  00:02:08.030000
# 4814     4815   JOHANNESSEN, Frans           1992  Denmark  00:02:08.300000
# 4690     4691    LAGERQVIST, Anton           1991   Sweden  00:02:08.210000
# 4867     4868       HULBOJ, Marcin           1996   Poland  00:02:08.350000
#
#       Time in secs  Butterfly  Backstroke  Breastroke  Freestyle  ...  \
# 3489        127.04      26.39       36.12       34.28      30.25  ...
# 4437        128.03      26.20       36.10       35.00      30.73  ...
# 4814        128.30      26.90       36.07       35.04      30.29  ...
# 4690        128.21      27.60       35.90       34.51      30.20  ...
# 4867        128.35      27.54       35.88       34.34      30.59  ...
#
#      Backstroke ratio mean  Breastroke ratio mean  Freestyle ratio mean  \
# 3489              1.124495               0.956417              1.009624
# 4437              1.123873               0.976505              1.025645
# 4814              1.122939               0.977621              1.010959
# 4690              1.117646               0.962834              1.007955
# 4867              1.117024               0.958091              1.020972
#
#       Butterfly ratio best  Backstroke ratio best  Breastroke ratio best  \
# 3489              1.083333               1.267368               1.168769
# 4437              1.075534               1.266667               1.193317
# 4814              1.104269               1.265614               1.194681
# 4690              1.133005               1.259649               1.176611
# 4867              1.130542               1.258947               1.170815
#
#       Freestyle ratio best  Worst style mean  Worst style best  \
# 3489              1.158116        Backstroke        Backstroke
# 4437              1.176493        Backstroke        Backstroke
# 4814              1.159648        Backstroke        Backstroke
# 4690              1.156202        Backstroke        Backstroke
# 4867              1.171133        Backstroke        Backstroke
#
#      Ranking interval
# 3489     (3400, 3500]
# 4437     (4400, 4500]
# 4814     (4800, 4925]
# 4690     (4600, 4700]
# 4867     (4800, 4925]
#
# [5 rows x 22 columns]

# %%
# There aren't impossible results for backstroke split, so computing mean reasult
backstroke_mean = float(splits_df[["Backstroke"]].mean())
print(backstroke_mean)
# Out:
# 28.5
# 32.1210764294049

# %% [markdown]
# ## Breastroke

# %%
splits_df.nsmallest(5, "Breastroke")
# Out:
#      Ranking          Swimmer name  Year of birth  Country             Time  \
# 0          1          CSEH, Laszlo           1985  Hungary  00:01:53.480000
# 16        17   KUDASHEV, Alexander           1995   Russia  00:01:56.300000
# 146      147  KHARLANOV, Alexander           1995   Russia  00:01:58.900000
# 2          3     BROMER, Viktor B.           1993  Denmark  00:01:54.470000
# 1          2       SWITKOWSKI, Jan           1994   Poland  00:01:54.100000
#
#      Time in secs  Butterfly  Backstroke  Breastroke  Freestyle       Date
# 0          113.48      25.18       29.03       29.33      29.94 2015-05-08
# 16         116.30      25.65       30.01       29.38      31.26 2015-04-21
# 146        118.90      26.50       30.43       29.40      32.57 2015-04-20
# 2          114.47      25.96       28.79       29.42      30.30 2015-04-08
# 1          114.10      25.96       29.22       29.68      29.24 2015-05-08

# %%
splits_df.nlargest(5, "Breastroke")
# Out:
#       Ranking         Swimmer name  Year of birth      Country  \
# 4807     4808  CRESCENZO, Riccardo           1997        Italy
# 4810     4811  CRESCENZO, Riccardo           1997        Italy
# 3400     3401     ISAKOV, Olexandr           1989      Ukraine
# 4768     4769          LIESS, Nils           1996  Switzerland
# 4771     4772          LIESS, Nils           1996  Switzerland
#
#                  Time  Time in secs  Butterfly  Backstroke  Breastroke  \
# 4807  00:02:08.300000        128.30      26.06       31.85       41.24
# 4810  00:02:08.300000        128.30      26.06       31.85       41.24
# 3400  00:02:06.910000        126.91      25.55       30.81       40.91
# 4768  00:02:08.270000        128.27      26.53       32.71       40.66
# 4771  00:02:08.270000        128.27      26.53       32.71       40.66
#
#       Freestyle  ... Backstroke ratio mean  Breastroke ratio mean  \
# 4807      29.15  ...              0.991561               1.150602
# 4810      29.15  ...              0.991561               1.150602
# 3400      29.64  ...              0.959183               1.141395
# 4768      28.37  ...              1.018334               1.134420
# 4771      28.37  ...              1.018334               1.134420
#
#       Freestyle ratio mean  Butterfly ratio best  Backstroke ratio best  \
# 4807              0.972910              1.069787               1.117544
# 4810              0.972910              1.069787               1.117544
# 3400              0.989265              1.048851               1.081053
# 4768              0.946877              1.089080               1.147719
# 4771              0.946877              1.089080               1.147719
#
#       Breastroke ratio best  Freestyle ratio best  Worst style mean  \
# 4807               1.406069              1.116003        Breastroke
# 4810               1.406069              1.116003        Breastroke
# 3400               1.394818              1.134763        Breastroke
# 4768               1.386294              1.086141        Breastroke
# 4771               1.386294              1.086141        Breastroke
#
#       Worst style best Ranking interval
# 4807        Breastroke     (4800, 4925]
# 4810        Breastroke     (4800, 4925]
# 3400        Breastroke     (3400, 3500]
# 4768        Breastroke     (4700, 4800]
# 4771        Breastroke     (4700, 4800]
#
# [5 rows x 22 columns]

# %%
# There aren't impossible results for breastroke split, so computing mean reasult
breastroke_mean = float(splits_df[["Breastroke"]].mean())
print(breastroke_mean)
# Out:
# 29.33
# 35.842114935822636

# %% [markdown]
# ## Freestyle

# %%
splits_df.nsmallest(5, "Freestyle")
# Out:
#       Ranking           Swimmer name  Year of birth    Country  \
# 2142     2143      MAJCHRZAK, Kacper           1992     Poland
# 2741     2742       STRAVIUS, Jeremy           1988     France
# 3806     3807  BERG EISCHEID, Moritz           1993      Spain
# 159       160          RAPSYS, Danas           1995  Lithuania
# 2027     2028         AGNEL, Yannick           1992     France
#
#                  Time  Time in secs  Butterfly  Backstroke  Breastroke  \
# 2142  00:02:04.960000        124.96      27.53       35.15       36.16
# 2741         00:02:06        126.00      24.36       34.46       40.22
# 3806  00:02:07.400000        127.40      26.82       34.79       38.69
# 159   00:01:59.140000        119.14      25.04       30.16       36.83
# 2027  00:02:04.710000        124.71      27.31       32.62       37.46
#
#       Freestyle       Date
# 2142      26.12 2019-03-23
# 2741      26.96 2016-03-29
# 3806      27.10 2018-10-02
# 159       27.11 2019-08-16
# 2027      27.32 2012-01-21

# %%
splits_df.nlargest(5, "Freestyle")
# Out:
#       Ranking          Swimmer name  Year of birth     Country  \
# 1890     1891    AVERCHENKO, Alexey           1993      Russia
# 1547     1548        GARDONIO, Luca           1979       Italy
# 1618     1619  STACCHIOTTI, Raphael           1992  Luxembourg
# 764       765       PALAZOV, Georgi           1980    Bulgaria
# 1992     1993        JAMMES, Thomas           1996      France
#
#                  Time  Time in secs  Butterfly  Backstroke  Breastroke  \
# 1890  00:02:04.450000        124.45      26.12       30.53       32.14
# 1547  00:02:03.880000        123.88      27.22       30.24       31.73
# 1618  00:02:03.990000        123.99      26.34       31.10       32.34
# 764   00:02:02.020000        122.02      26.04       29.99       31.81
# 1992  00:02:04.640000        124.64      27.42       31.14       31.94
#
#       Freestyle  ... Backstroke ratio mean  Breastroke ratio mean  \
# 1890      35.66  ...              0.950466               0.896710
# 1547      34.69  ...              0.941438               0.885271
# 1618      34.21  ...              0.968212               0.902291
# 764       34.18  ...              0.933655               0.887503
# 1992      34.14  ...              0.969457               0.891130
#
#       Freestyle ratio mean  Butterfly ratio best  Backstroke ratio best  \
# 1890              1.190188              1.072250               1.071228
# 1547              1.157813              1.117406               1.061053
# 1618              1.141793              1.081281               1.091228
# 764               1.140792              1.068966               1.052281
# 1992              1.139457              1.125616               1.092632
#
#       Breastroke ratio best  Freestyle ratio best  Worst style mean  \
# 1890               1.095806              1.365237         Freestyle
# 1547               1.081827              1.328101         Freestyle
# 1618               1.102625              1.309724         Freestyle
# 764                1.084555              1.308576         Freestyle
# 1992               1.088987              1.307044         Freestyle
#
#       Worst style best Ranking interval
# 1890         Freestyle     (1800, 1900]
# 1547         Freestyle     (1500, 1600]
# 1618         Freestyle     (1600, 1700]
# 764          Freestyle       (700, 800]
# 1992         Freestyle     (1900, 2000]
#
# [5 rows x 22 columns]

# %%
# There aren't impossible results for freestyle split, so computing mean reasult
freestyle_mean = float(splits_df[["Freestyle"]].mean())
print(freestyle_mean)
# Out:
# 26.12
# 29.961648191365228

# %%
splits_df["Butterfly ratio"] = splits_df.apply(lambda row: row["Butterfly"]/butterfly_mean, axis = 1)
splits_df["Backstroke ratio"] = splits_df.apply(lambda row: row["Backstroke"]/backstroke_mean, axis = 1)
splits_df["Breastroke ratio"] = splits_df.apply(lambda row: row["Breastroke"]/breastroke_mean, axis = 1)
splits_df["Freestyle ratio"] = splits_df.apply(lambda row: row["Freestyle"]/freestyle_mean, axis = 1)

# %%
splits_df
# Out:
#       Ranking          Swimmer name  Year of birth  Country             Time  \
# 0           1          CSEH, Laszlo           1985  Hungary  00:01:53.480000
# 1           2       SWITKOWSKI, Jan           1994   Poland  00:01:54.100000
# 2           3     BROMER, Viktor B.           1993  Denmark  00:01:54.470000
# 3           4      KENDERESI, Tamas           1996  Hungary  00:01:54.790000
# 4           5      KOPTELOV, Evgeny           1993   Russia  00:01:54.790000
# ...       ...                   ...            ...      ...              ...
# 4918     4919          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4920     4921  IPSEN, Anton Oerskov           1994  Denmark  00:02:08.390000
# 4921     4922           MAURI, Luca           1995    Italy  00:02:08.390000
# 4923     4924          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4924     4925       CASTERA, Mathis           1996   France  00:02:08.390000
#
#       Time in secs  Butterfly  Backstroke  Breastroke  Freestyle       Date  \
# 0           113.48      25.18       29.03       29.33      29.94 2015-05-08
# 1           114.10      25.96       29.22       29.68      29.24 2015-05-08
# 2           114.47      25.96       28.79       29.42      30.30 2015-04-08
# 3           114.79      26.55       29.89       29.74      28.61 2015-06-30
# 4           114.79      26.04       29.15       30.17      29.43 2015-07-07
# ...            ...        ...         ...         ...        ...        ...
# 4918        128.39      27.53       33.61       36.20      31.05 2018-08-07
# 4920        128.39      27.78       33.98       36.94      29.69 2012-07-13
# 4921        128.39      27.88       34.64       36.33      29.54 2012-08-08
# 4923        128.39      27.53       33.61       36.20      31.05 2018-08-07
# 4924        128.39      29.35       32.20       38.37      28.47 2016-07-30
#
#       Butterfly ratio mean  Backstroke ratio mean  Breastroke ratio mean  \
# 0                 0.935648               0.903768               0.818311
# 1                 0.964632               0.909683               0.828076
# 2                 0.964632               0.896296               0.820822
# 3                 0.986555               0.930542               0.829750
# 4                 0.967605               0.907504               0.841747
# ...                    ...                    ...                    ...
# 4918              1.022971               1.046353               1.009985
# 4920              1.032260               1.057872               1.030631
# 4921              1.035976               1.078420               1.013612
# 4923              1.022971               1.046353               1.009985
# 4924              1.090599               1.002457               1.070528
#
#       Freestyle ratio mean  Butterfly ratio best  Backstroke ratio best  \
# 0                 0.999277              1.033662               1.018596
# 1                 0.975914              1.065681               1.025263
# 2                 1.011293              1.065681               1.010175
# 3                 0.954887              1.089901               1.048772
# 4                 0.982256              1.068966               1.022807
# ...                    ...                   ...                    ...
# 4918              1.036325              1.130131               1.179298
# 4920              0.990933              1.140394               1.192281
# 4921              0.985927              1.144499               1.215439
# 4923              1.036325              1.130131               1.179298
# 4924              0.950215              1.204844               1.129825
#
#       Breastroke ratio best  Freestyle ratio best
# 0                  1.000000              1.146248
# 1                  1.011933              1.119449
# 2                  1.003069              1.160031
# 3                  1.013979              1.095329
# 4                  1.028640              1.126723
# ...                     ...                   ...
# 4918               1.234231              1.188744
# 4920               1.259461              1.136677
# 4921               1.238663              1.130934
# 4923               1.234231              1.188744
# 4924               1.308217              1.089969
#
# [3428 rows x 19 columns]

# %%
def worst_style_checker(fly, back, frog, free):
    ratios = [fly, back, frog, free]
    if max(ratios) == fly:
        return "Butterfly"
    elif max(ratios) == back:
        return "Backstroke"
    elif max(ratios) == frog:
        return "Breastroke"
    else:
        return "Freestyle"

# %%
splits_df["Worst style"] = splits_df.apply(lambda row: worst_style_checker(row["Butterfly ratio"], 
                                                                           row["Backstroke ratio"], 
                                                                           row["Breastroke ratio"], 
                                                                           row["Freestyle ratio"]), axis=1)

# %%
splits_df["Ranking interval"] = pd.cut(splits_df.Ranking,[0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000,
                                                         1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900,
                                                         2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800,
                                                         2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 
                                                         3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600,
                                                         4700, 4800, 4925],right=True)

# %%
splits_df
# Out:
#       Ranking          Swimmer name  Year of birth  Country             Time  \
# 0           1          CSEH, Laszlo           1985  Hungary  00:01:53.480000
# 1           2       SWITKOWSKI, Jan           1994   Poland  00:01:54.100000
# 2           3     BROMER, Viktor B.           1993  Denmark  00:01:54.470000
# 3           4      KENDERESI, Tamas           1996  Hungary  00:01:54.790000
# 4           5      KOPTELOV, Evgeny           1993   Russia  00:01:54.790000
# ...       ...                   ...            ...      ...              ...
# 4918     4919          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4920     4921  IPSEN, Anton Oerskov           1994  Denmark  00:02:08.390000
# 4921     4922           MAURI, Luca           1995    Italy  00:02:08.390000
# 4923     4924          LEANDER, Tor           1999   Sweden  00:02:08.390000
# 4924     4925       CASTERA, Mathis           1996   France  00:02:08.390000
#
#       Time in secs  Butterfly  Backstroke  Breastroke  Freestyle  ...  \
# 0           113.48      25.18       29.03       29.33      29.94  ...
# 1           114.10      25.96       29.22       29.68      29.24  ...
# 2           114.47      25.96       28.79       29.42      30.30  ...
# 3           114.79      26.55       29.89       29.74      28.61  ...
# 4           114.79      26.04       29.15       30.17      29.43  ...
# ...            ...        ...         ...         ...        ...  ...
# 4918        128.39      27.53       33.61       36.20      31.05  ...
# 4920        128.39      27.78       33.98       36.94      29.69  ...
# 4921        128.39      27.88       34.64       36.33      29.54  ...
# 4923        128.39      27.53       33.61       36.20      31.05  ...
# 4924        128.39      29.35       32.20       38.37      28.47  ...
#
#      Backstroke ratio mean  Breastroke ratio mean  Freestyle ratio mean  \
# 0                 0.903768               0.818311              0.999277
# 1                 0.909683               0.828076              0.975914
# 2                 0.896296               0.820822              1.011293
# 3                 0.930542               0.829750              0.954887
# 4                 0.907504               0.841747              0.982256
# ...                    ...                    ...                   ...
# 4918              1.046353               1.009985              1.036325
# 4920              1.057872               1.030631              0.990933
# 4921              1.078420               1.013612              0.985927
# 4923              1.046353               1.009985              1.036325
# 4924              1.002457               1.070528              0.950215
#
#       Butterfly ratio best  Backstroke ratio best  Breastroke ratio best  \
# 0                 1.033662               1.018596               1.000000
# 1                 1.065681               1.025263               1.011933
# 2                 1.065681               1.010175               1.003069
# 3                 1.089901               1.048772               1.013979
# 4                 1.068966               1.022807               1.028640
# ...                    ...                    ...                    ...
# 4918              1.130131               1.179298               1.234231
# 4920              1.140394               1.192281               1.259461
# 4921              1.144499               1.215439               1.238663
# 4923              1.130131               1.179298               1.234231
# 4924              1.204844               1.129825               1.308217
#
#       Freestyle ratio best  Worst style mean  Worst style best  \
# 0                 1.146248         Freestyle         Freestyle
# 1                 1.119449         Freestyle         Freestyle
# 2                 1.160031         Freestyle         Freestyle
# 3                 1.095329         Butterfly         Freestyle
# 4                 1.126723         Freestyle         Freestyle
# ...                    ...               ...               ...
# 4918              1.188744        Backstroke        Breastroke
# 4920              1.136677        Backstroke        Breastroke
# 4921              1.130934        Backstroke        Breastroke
# 4923              1.188744        Backstroke        Breastroke
# 4924              1.089969         Butterfly        Breastroke
#
#      Ranking interval
# 0            (0, 100]
# 1            (0, 100]
# 2            (0, 100]
# 3            (0, 100]
# 4            (0, 100]
# ...               ...
# 4918     (4800, 4925]
# 4920     (4800, 4925]
# 4921     (4800, 4925]
# 4923     (4800, 4925]
# 4924     (4800, 4925]
#
# [3428 rows x 22 columns]

# %%
plot_grpby = splits_df.groupby(['Worst style', 'Ranking interval'])

# %%
plot_df = plot_grpby.size().reset_index()

# %%
plot_df
# Out:
#     Worst style mean Ranking interval  0
# 0         Backstroke         (0, 100]  3
# 1         Backstroke       (100, 200]  6
# 2         Backstroke       (200, 300]  6
# 3         Backstroke       (300, 400]  3
# 4         Backstroke       (400, 500]  5
# ..               ...              ... ..
# 191        Freestyle     (4400, 4500]  1
# 192        Freestyle     (4500, 4600]  6
# 193        Freestyle     (4600, 4700]  7
# 194        Freestyle     (4700, 4800]  5
# 195        Freestyle     (4800, 4925]  4
#
# [196 rows x 3 columns]

# %%
breastroke_plot = plot_df[plot_df["Worst style"] == "Breastroke"].reset_index(drop = True)

# %%
fig = plt.figure()
sns.set()

x = breastroke_plot['Ranking interval']
y = breastroke_plot[0]

ax=fig.add_axes([0,0,1,1])
ax.xaxis.set_major_locator(plt.MaxNLocator(5))

ax.scatter(x.astype(str), y, color='b')
ax.set_xlabel('Ranking place')
ax.set_ylabel('Number of swimmers')
ax.set_title('Breastroke as the worst style', size=25)


z = np.polyfit(x.index.values, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x.index.values),"r--")
plt.show()

# %%
freestyle_plot = plot_df[plot_df["Worst style"] == "Freestyle"].reset_index(drop = True)

# %%
fig4 = plt.figure()

x4 = freestyle_plot['Ranking interval']
y4 = freestyle_plot[0]

ax4 = fig4.add_axes([0,0,1,1])
ax4.xaxis.set_major_locator(plt.MaxNLocator(5))

ax4.scatter(x4.astype(str), y4, color='b')
ax4.set_xlabel('Ranking place')
ax4.set_ylabel('Number of swimmers')
ax4.set_title('Freestyle as the worst style', size=25)


z4 = np.polyfit(x4.index.values, y4, 1)
p4 = np.poly1d(z4)
plt.plot(x4,p4(x4.index.values),"r--")
plt.show()

# %%
butterfly_plot = plot_df[plot_df["Worst style"] == "Butterfly"].reset_index(drop = True)

# %%
fig1 = plt.figure()

x1 = butterfly_plot['Ranking interval']
y1 = butterfly_plot[0]

ax1 = fig1.add_axes([0,0,1,1])
ax1.xaxis.set_major_locator(plt.MaxNLocator(5))

ax1.scatter(x1.astype(str), y1, color='b')
ax1.set_xlabel('Ranking place')
ax1.set_ylabel('Number of swimmers')
ax1.set_title('Butterfly as the worst style', size=25)


z1 = np.polyfit(x1.index.values, y1, 1)
p1 = np.poly1d(z1)
plt.plot(x1,p1(x1.index.values),"r--")
plt.show()

# %%
backstroke_plot = plot_df[plot_df["Worst style"] == "Backstroke"].reset_index(drop = True)

# %%
fig2 = plt.figure()

x2 = backstroke_plot['Ranking interval']
y2 = backstroke_plot[0]

ax2 = fig2.add_axes([0,0,1,1])
ax2.xaxis.set_major_locator(plt.MaxNLocator(4))

ax2.scatter(x2.astype(str), y2, color='b')
ax2.set_xlabel('Ranking places interval')
ax2.set_ylabel('Number of swimmers for interval')
ax2.set_title('Backstroke as the worst style', size=25, fontweight='bold')


z2 = np.polyfit(x2.index.values, y2, 1)
p2 = np.poly1d(z2)
plt.plot(x2,p2(x2.index.values),"r--")
plt.show()

# %%
podzial = (splits_df.groupby([pd.Grouper(key="Ranking interval"), "Worst style mean"])
                            .size()
                            .unstack(fill_value=0))

# %%
analiza = podzial.groupby(podzial.index).sum()
analiza
# Out:
# Worst style mean  Backstroke  Breastroke  Butterfly  Freestyle
# Ranking interval
# (0, 100]                   3          19         12         51
# (100, 200]                 6          13         14         38
# (200, 300]                 6          16         11         42
# (300, 400]                 3          28         11         36
# (400, 500]                 5          22         13         36
# (500, 600]                12          17          4         38
# (600, 700]                12          20         14         23
# (700, 800]                10          25         13         24
# (800, 900]                19          17          9         27
# (900, 1000]               13          23         13         25
# (1000, 1100]              18          21         16         23
# (1100, 1200]              12          19          8         33
# (1200, 1300]              16          31         14         21
# (1300, 1400]              13          21         10         28
# (1400, 1500]              13          25         11         23
# (1500, 1600]              15          24          7         28
# (1600, 1700]              13          20         13         14
# (1700, 1800]              15          16          9         29
# (1800, 1900]              20          20         13         17
# (1900, 2000]               7          26         10         19
# (2000, 2100]              29          23          7         12
# (2100, 2200]              21          35          7          9
# (2200, 2300]              18          29         10         16
# (2300, 2400]              20          35          8          9
# (2400, 2500]              19          28         12          5
# (2500, 2600]              11          34         11         13
# (2600, 2700]              15          37          8         14
# (2700, 2800]              21          40          8          3
# (2800, 2900]              24          32          5          5
# (2900, 3000]              23          31          7          8
# (3000, 3100]              18          34          8          7
# (3100, 3200]              20          37          5          8
# (3200, 3300]              30          29          7          5
# (3300, 3400]              25          27          9          3
# (3400, 3500]              18          33          5          5
# (3500, 3600]              21          37          3          3
# (3600, 3700]              24          31         10          6
# (3700, 3800]              22          35          9          5
# (3800, 3900]              15          32          3          6
# (3900, 4000]              21          25          9          6
# (4000, 4100]              19          40          7          7
# (4100, 4200]              19          42          7          6
# (4200, 4300]              14          29         12          3
# (4300, 4400]              25          21          7          8
# (4400, 4500]              14          40          9          1
# (4500, 4600]              20          38          5          6
# (4600, 4700]              16          41          8          7
# (4700, 4800]              19          29          4          5
# (4800, 4925]              30          48          6          4

# %%
# plt.title('Breastroke as the worst style')
plt.style.use('fivethirtyeight')
plt.xlabel('Ranking interval')
plt.ylabel("Number of swimmers")
plt.suptitle('Breastroke as the worst style', fontsize='x-large', fontweight='bold')
ax.xaxis.set_major_locator(plt.MaxNLocator(10)
# sns.set()
analiza.Breastroke.plot.bar()
# Out:
#   File "<ipython-input-57-af48c2f327a5>", line 8
#     analiza.Breastroke.plot.bar()
#           ^
# SyntaxError: invalid syntax

# %%
analiza.Butterfly.plot.bar()
